# %%
# Membaca file
# ./ apabila dalam folder yang sama
# ../ apabila dalam sub folder yang sama
file = open("./test.txt", "r")  #read file
content = file.read()
print(content)
file.close()
# Out:
# Helo teman-teman koding studio
# sekarang kita akan belajar pyhton

# %%
# menulis file
file = open("./ random.txt","w")   #menulis file
file.write("ini hanya teks random")
file.close()
